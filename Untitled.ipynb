# %%
from SEIQR_Int import SEIQRInt
import pandas as pd

# %%
params = dict(
    dInf=2.3,
    dInc=5.2,
    R0_I=1.8,
    R0_Q=0,
    R0_Int=1.8,
    epsilon_I=0.2,
    epsilon_E=0.01,
    epsilon_IInt=0,
    epsilon_EInt=0,
    Imp_I=2,
    Imp_E=8,
)
Y = dict(S=65000000,E=0,I=0,Q=0,R=0,E_Int=0,I_Int=0,Q_Int=0,R_Int=0)
T = 90

seiqr = SEIQRInt(Y=Y,T=T,params=params)
df = pd.DataFrame(seiqr.run(),columns = Y.keys())

# %%
#df['S'].plot()
df['R'].diff().plot()

# %%
df['E_Int'].plot()
df['I_Int'].plot()
